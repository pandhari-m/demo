# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Advertising .csv")

# %%
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data=data.rename(columns={'Unnamed: 0':'ID'})

# %%
data.head()
# Out:
#    ID     TV  Radio  Newspaper  Sales
# 0   1  230.1   37.8       69.2   22.1
# 1   2   44.5   39.3       45.1   10.4
# 2   3   17.2   45.9       69.3    9.3
# 3   4  151.5   41.3       58.5   18.5
# 4   5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#       ID     TV  Radio  Newspaper  Sales
# 195  196   38.2    3.7       13.8    7.6
# 196  197   94.2    4.9        8.1    9.7
# 197  198  177.0    9.3        6.4   12.8
# 198  199  283.6   42.0       66.2   25.5
# 199  200  232.1    8.6        8.7   13.4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         200 non-null    int64
#  1   TV         200 non-null    float64
#  2   Radio      200 non-null    float64
#  3   Newspaper  200 non-null    float64
#  4   Sales      200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#                ID          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data.shape
# Out:
# (200, 5)

# %%
data.isnull().sum()
# Out:
# ID           0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.corr()
# Out:
#                  ID        TV     Radio  Newspaper     Sales
# ID         1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV         0.017715  1.000000  0.054809   0.056648  0.782224
# Radio     -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales     -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
data['TV'].unique()
# Out:
# array([230.1,  44.5,  17.2, 151.5, 180.8,   8.7,  57.5, 120.2,   8.6,
#        199.8,  66.1, 214.7,  23.8,  97.5, 204.1, 195.4,  67.8, 281.4,
#         69.2, 147.3, 218.4, 237.4,  13.2, 228.3,  62.3, 262.9, 142.9,
#        240.1, 248.8,  70.6, 292.9, 112.9,  97.2, 265.6,  95.7, 290.7,
#        266.9,  74.7,  43.1, 228. , 202.5, 177. , 293.6, 206.9,  25.1,
#        175.1,  89.7, 239.9, 227.2,  66.9, 100.4, 216.4, 182.6, 262.7,
#        198.9,   7.3, 136.2, 210.8, 210.7,  53.5, 261.3, 239.3, 102.7,
#        131.1,  69. ,  31.5, 139.3, 216.8, 199.1, 109.8,  26.8, 129.4,
#        213.4,  16.9,  27.5, 120.5,   5.4, 116. ,  76.4, 239.8,  75.3,
#         68.4, 213.5, 193.2,  76.3, 110.7,  88.3, 134.3,  28.6, 217.7,
#        250.9, 107.4, 163.3, 197.6, 184.9, 289.7, 135.2, 222.4, 296.4,
#        280.2, 187.9, 238.2, 137.9,  25. ,  90.4,  13.1, 255.4, 225.8,
#        241.7, 175.7, 209.6,  78.2,  75.1, 139.2, 125.7,  19.4, 141.3,
# ...

# %%
data.loc[(data['TV']>=200) & (data['Sales']>=14)]
# Out:
#       ID     TV  Radio  Newspaper  Sales
# 0      1  230.1   37.8       69.2   22.1
# 11    12  214.7   24.0        4.0   17.4
# 14    15  204.1   32.9       46.0   19.0
# 17    18  281.4   39.6       55.8   24.4
# 20    21  218.4   27.7       53.4   18.0
# 23    24  228.3   16.9       26.2   15.5
# 27    28  240.1   16.7       22.9   15.9
# 28    29  248.8   27.1       22.9   18.9
# 30    31  292.9   28.3       43.2   21.4
# 33    34  265.6   20.0        0.3   17.4
# 36    37  266.9   43.8        5.0   25.4
# 39    40  228.0   37.7       32.0   21.5
# 40    41  202.5   22.3       31.6   16.6
# 42    43  293.6   27.7        1.8   20.7
# 47    48  239.9   41.5       18.5   23.2
# 48    49  227.2   15.8       49.9   14.8
# 52    53  216.4   41.7       39.6   22.6
# 54    55  262.7   28.8       15.9   20.2
# 58    59  210.8   49.6       37.7   23.8
# 59    60  210.7   29.5        9.3   18.4
# 61    62  261.3   42.7       54.7   24.2
# 62    63  239.3   15.5       27.3   15.7
# ...

# %%
data.columns
# Out:
# Index(['ID', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
data[['TV','Sales']]
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
data[0:20]
# Out:
#     ID     TV  Radio  Newspaper  Sales
# 0    1  230.1   37.8       69.2   22.1
# 1    2   44.5   39.3       45.1   10.4
# 2    3   17.2   45.9       69.3    9.3
# 3    4  151.5   41.3       58.5   18.5
# 4    5  180.8   10.8       58.4   12.9
# 5    6    8.7   48.9       75.0    7.2
# 6    7   57.5   32.8       23.5   11.8
# 7    8  120.2   19.6       11.6   13.2
# 8    9    8.6    2.1        1.0    4.8
# 9   10  199.8    2.6       21.2   10.6
# 10  11   66.1    5.8       24.2    8.6
# 11  12  214.7   24.0        4.0   17.4
# 12  13   23.8   35.1       65.9    9.2
# 13  14   97.5    7.6        7.2    9.7
# 14  15  204.1   32.9       46.0   19.0
# 15  16  195.4   47.7       52.9   22.4
# 16  17   67.8   36.6      114.0   12.5
# 17  18  281.4   39.6       55.8   24.4
# 18  19   69.2   20.5       18.3   11.3
# 19  20  147.3   23.9       19.1   14.6

# %%
data.Sales.mean()
# Out:
# 14.0225

# %%
data.TV.mean()
# Out:
# 147.0425

# %%
data.TV.min()
# Out:
# 0.7

# %%
data.loc[(data['TV']==0.7)]
# Out:
#       ID   TV  Radio  Newspaper  Sales
# 130  131  0.7   39.6        8.7    1.6

# %%
data.TV.max()
# Out:
# 296.4

# %%
data.TV.value_counts()
# Out:
# TV
# 199.8    2
# 109.8    2
# 17.2     2
# 177.0    2
# 222.4    2
#         ..
# 139.3    1
# 216.8    1
# 199.1    1
# 26.8     1
# 232.1    1
# Name: count, Length: 190, dtype: int64

# %%
data.sort_values('TV',ignore_index=True)
# Out:
#       ID     TV  Radio  Newspaper  Sales
# 0    131    0.7   39.6        8.7    1.6
# 1    156    4.1   11.6        5.7    3.2
# 2     79    5.4   29.9        9.4    5.3
# 3     57    7.3   28.1       41.4    5.5
# 4    127    7.8   38.9       50.6    6.6
# ..   ...    ...    ...        ...    ...
# 195   99  289.7   42.3       51.2   25.4
# 196   36  290.7    4.1        8.5   12.8
# 197   31  292.9   28.3       43.2   21.4
# 198   43  293.6   27.7        1.8   20.7
# 199  102  296.4   36.3      100.9   23.8
#
# [200 rows x 5 columns]

# %%
data.sort_values(by=['TV','Radio'],ascending=[1,0],ignore_index=True)
# Out:
#       ID     TV  Radio  Newspaper  Sales
# 0    131    0.7   39.6        8.7    1.6
# 1    156    4.1   11.6        5.7    3.2
# 2     79    5.4   29.9        9.4    5.3
# 3     57    7.3   28.1       41.4    5.5
# 4    127    7.8   38.9       50.6    6.6
# ..   ...    ...    ...        ...    ...
# 195   99  289.7   42.3       51.2   25.4
# 196   36  290.7    4.1        8.5   12.8
# 197   31  292.9   28.3       43.2   21.4
# 198   43  293.6   27.7        1.8   20.7
# 199  102  296.4   36.3      100.9   23.8
#
# [200 rows x 5 columns]

# %%
data.groupby(data['TV']).count()
# Out:
#        ID  Radio  Newspaper  Sales
# TV
# 0.7     1      1          1      1
# 4.1     1      1          1      1
# 5.4     1      1          1      1
# 7.3     1      1          1      1
# 7.8     1      1          1      1
# ...    ..    ...        ...    ...
# 289.7   1      1          1      1
# 290.7   1      1          1      1
# 292.9   1      1          1      1
# 293.6   1      1          1      1
# 296.4   1      1          1      1
#
# [190 rows x 4 columns]

# %%
data.groupby(data['ID']).max()
# Out:
#         TV  Radio  Newspaper  Sales
# ID
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sns.lineplot(x='TV',y='Sales', data=data , ci=None)
plt.show()
# Out:
# C:\Users\LAPPKART.COM\AppData\Local\Temp\ipykernel_1280\902452837.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='TV',y='Sales', data=data , ci=None)

# %%
sns.boxplot(data=data,  hue='sales')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 sns.boxplot(data=data,  hue='sales')
#
# File ~\Documents\New folder\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
#    1602         color=color,
# ...

# %%
sns.lineplot(x='TV', y='Sales', data=data, ci=None)
plt.show()
# Out:
# C:\Users\LAPPKART.COM\AppData\Local\Temp\ipykernel_1280\2802744141.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='TV', y='Sales', data=data, ci=None)

# %%
sns.scatterplot(x='TV',y='Sales',data=data)
plt.show()
plt.title('TV advertising vs sales')
# Out:
# Text(0.5, 1.0, 'TV advertising vs sales')

# %%
sns.scatterplot(x='Radio',y='Sales',data=data)
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(x='Newspaper',y='Sales',data=data)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.barplot(x='TV',y='Sales',data=data)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.countplot(x='Sales', data=data)
plt.show()

# %%
sns.histplot(x='Sales' , data=data , kde=True)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(x='TV',data=data,kde=True)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.heatmap(data, annot=True)
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
sns.boxplot(data=data[['TV','Radio','Newspaper','Sales']])
plt.title('Boxplot of Advertising chanels and Sales')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
ad_spend=data[['TV','Radio','Newspaper',]].sum()

# %%
plt.pie(ad_spend,labels=ad_spend.index,autopct='%1.1f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x25e4ae7fda0>,
# ...
#  [Text(-0.8203908042442681, -0.7327748141901734, 'TV'),
#   Text(1.0654868557395674, 0.2733820774048847, 'Radio'),
#   Text(0.5058927424826051, 0.9767663656696154, 'Newspaper')],
#  [Text(-0.4474858932241462, -0.39969535319464006, '73.2%'),
#   Text(0.5811746485852185, 0.1491174967663007, '11.6%'),
#   Text(0.2759414958996027, 0.5327816540016084, '15.2%')])
